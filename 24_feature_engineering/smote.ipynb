# %% [markdown]
# SMOTE: creating synthetic instances of the minority class by interpolating between existing instances

# %%
from sklearn.datasets import make_classification
x,y = make_classification(
    n_samples = 1000,
    n_features=2,
    n_redundant=0,
    n_clusters_per_class=1,
    weights= [0.90])

# %%
import pandas as pd
df1 = pd.DataFrame(x, columns=['f1','f2'])
df2 = pd.DataFrame(y,columns = ['target'])
final_df = pd.concat([df1,df2],axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0  1.241168  0.741717       0
# 1  0.679812  1.339560       0
# 2  1.182684  0.786362       0
# 3  1.108546  0.845547       0
# 4  1.317393  0.657366       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    901
# 1     99
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])

# %% [markdown]
# ### applying smote

# %%
# !pip install imblearn
# Out:
# ...
# WARNING: You are using pip version 21.1.1; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\users\lenovo\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
from imblearn.over_sampling import SMOTE

#transform dataset 
oversample = SMOTE()
x,y = oversample.fit_resample(final_df[['f1','f2']],fina_df['target'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from imblearn.over_sampling import SMOTE
#       3 #transform dataset
#       4 oversample = SMOTE()
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
import sys
# !{sys.executable} -m pip install imbalanced-learn
# Out:
# 'd:\machine' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from imblearn.over_sampling import SMOTE

#transform dataset 
oversample = SMOTE()
x,y = oversample.fit_resample(final_df[['f1','f2']],fina_df['target'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from imblearn.over_sampling import SMOTE
#       3 #transform dataset
#       4 oversample = SMOTE()
#
# ModuleNotFoundError: No module named 'imblearn'
